# %%
means25 = []

for i in range(1000):
    a = np.random.choice(s_1, size = 25, replace=False)
    means25.append(np.mean(a))

means100 = []

for i in range(1000):
    a = np.random.choice(s_1, size = 100, replace=False)
    means100.append(np.mean(a))

means400 = []

for i in range(1000):
    a = np.random.choice(s_1, size = 400, replace=False)
    means400.append(np.mean(a))

fig, axs = plt.subplots(figsize=(12,8))
axs.hist(means25, color="y", alpha=0.5, bins= np.linspace(1.1, 3.2, 50), label="N = 25")
axs.hist(means100, color="r", alpha=0.5, bins= np.linspace(1.1, 3.2, 50), label="N = 100")
axs.hist(means400, color="b", alpha=0.5, bins= np.linspace(1.1, 3.2, 50), label="N = 400")


plt.title("Distribution of Means", fontsize=20)
axs.set_xlabel("Values", fontsize=18)
axs.set_ylabel("Frequency", fontsize=18)
axs.tick_params(labelsize=15)
axs.legend(prop={'size': 15})
axs.axvline(x = np.mean(s_1), color='r', label='Mean')

plt.show()

std_25 = np.std(means25)
se_25 = std_25/5
lower25 = np.mean(means25) - 2*se_25
upper25 = np.mean(means25) + 2*se_25
print(f'The standard error is {se_25}')
print(f'The CI for the distribution of sample size 25 is [{lower25}, {upper25}]')

std_100 = np.std(means100)
se_100 = std_25/10
lower100 = np.mean(means25) - 2*se_100
upper100 = np.mean(means25) + 2*se_100
print(f'The standard error is {se_100}')
print(f'The CI for the distribution of sample size 100 is [{lower100}, {upper100}]')

std_400 = np.std(means100)
se_400 = std_25/20
lower400 = np.mean(means25) - 2*se_400
upper400 = np.mean(means25) + 2*se_400
print(f'The standard error is {se_400}')
print(f'The CI for the distribution of sample size 100 is [{lower400}, {upper400}]')
# Out:
# The standard error is 0.05578242533271569
# The CI for the distribution of sample size 25 is [1.8882751493345686, 2.1114048506654313]
# The standard error is 0.027891212666357846
# The CI for the distribution of sample size 100 is [1.9440575746672843, 2.0556224253327158]
# The standard error is 0.013945606333178923
# The CI for the distribution of sample size 100 is [1.9719487873336423, 2.027731212666358]

# %%
print('Max:',max(means25))
print('Min:',min(means25))
# Out:
# Max: 3.16
# Min: 1.12
