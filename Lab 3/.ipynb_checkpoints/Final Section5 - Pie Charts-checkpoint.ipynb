# %% [markdown]
# # Pie Charts
#
# We will be creating pie charts in this notebook.

# %% [markdown]
# This is the code that can create pie charts:
#
# ```Python
# import matplotlib.pyplot as plt
#
# fig, axs = plt.subplots(figsize=(5, 5)) # change figure size here
# axs.pie(y_values, labels=x_values, autopct='%1.1f%%',
#         shadow=True, startangle=90)
#
# axs.axis('equal')
# plt.title('Main title',fontweight="bold", fontsize=15, pad=20)
# plt.show()
# ```

# %%
# show the code without autopct
# Segmented bar chart
# Show how to create a simple table
# 1 exercise (horizontal)

# %% [markdown]
# As before, you have to specify the values in `y_values` and labels in `x_values`

# %%
import pandas as pd
df = pd.read_csv('Data/COVID.csv')

# %%
df
# Out:
#       Race    Cases  Deaths  Population
# 0    White  2010404   96979   197277789
# 1    Black   824169   39648    39445495
# 2    Latin  1030154   36882    56510571
# 3    Asian   123389    6891    16989540
# 4    Other   452013    8694    10781012
# 5  Unknown  2646058   11052           0

# %% [markdown]
# We will create a pie chart of the population in the U.S.

# %%
y_values = df['Population']
x_values = df['Race']

import matplotlib.pyplot as plt

fig, axs = plt.subplots(figsize=(5, 5)) # change figure size here
axs.pie(y_values, labels=x_values, autopct='%1.1f%%',
         startangle=90)

axs.axis('equal')
plt.title('Main title',fontweight="bold", fontsize=15, pad=20)
plt.show()

# %% [markdown]
# Good, but we see the unknown, which is undesired in this case. `df['Column name']` is the same as lists, and we can delete the final element in the list by: `list_name[:-1]`

# %%
y_values = df['Population'][:-1]
x_values = df['Race'][:-1]

import matplotlib.pyplot as plt

fig, axs = plt.subplots(figsize=(5, 5)) # change figure size here
axs.pie(y_values, labels=x_values, autopct='%1.1f%%',
        shadow=True, startangle=90)

axs.axis('equal')
plt.title('Population in the U.S.',fontweight="bold", fontsize=15, pad=20)
plt.show()

# %% [markdown]
# Looks great. We will can also make the labels go to the right by using the following code:
#
# ```Python
# import matplotlib.pyplot as plt
#
# percent = y_values / sum(y_values) * 100
# label = [[] for i in range(len(x_values))]
# for i in range(len(x_values)):
#     label[i] = '{} ({:.2f}%)'.format(x_values[i],percent[i])
#
# fig, axs = plt.subplots(figsize=(5, 5)) # change figure size here
# pie = axs.pie(y_values, shadow=True, startangle=90)
# axs.axis('equal')
# plt.legend(pie[0],label, bbox_to_anchor=(1.3,0.5), loc="center right", fontsize=12,
#            bbox_transform=plt.gcf().transFigure)
# plt.title('Main title',fontweight="bold", fontsize=15, pad=20)
# plt.show()
# ```

# %%
y_values = df['Population'][:-1]
x_values = df['Race'][:-1]

import matplotlib.pyplot as plt

percent = y_values / sum(y_values) * 100
label = [[] for i in range(len(x_values))]
for i in range(len(x_values)):
    label[i] = '{} ({:.2f}%)'.format(x_values[i],percent[i])

fig, axs = plt.subplots(figsize=(5, 5)) # change figure size here
pie = axs.pie(y_values, shadow=True, startangle=90)
axs.axis('equal')
plt.legend(pie[0],label, bbox_to_anchor=(1.3,0.5), loc="center right", fontsize=12, 
           bbox_transform=plt.gcf().transFigure)
plt.title('Population in the U.S.',fontweight="bold", fontsize=15, pad=20)
plt.show()

# %% [markdown]
# Now, we will be visualizing COVID-19 death cases

# %%
df
# Out:
#       Race    Cases  Deaths  Population
# 0    White  2010404   96979   197277789
# 1    Black   824169   39648    39445495
# 2    Latin  1030154   36882    56510571
# 3    Asian   123389    6891    16989540
# 4    Other   452013    8694    10781012
# 5  Unknown  2646058   11052           0

# %%
y_values = df['Deaths']
x_values = df['Race']

import matplotlib.pyplot as plt

fig, axs = plt.subplots(figsize=(5, 5)) # change figure size here
axs.pie(y_values, labels=x_values, autopct='%1.1f%%',
        shadow=True, startangle=90)

axs.axis('equal')
plt.title('COVID-19 Deaths Broken Down by Race',fontweight="bold", fontsize=15, pad=20)
plt.show()

# %%
y_values = df['Deaths']
x_values = df['Race']

import matplotlib.pyplot as plt

percent = y_values / sum(y_values) * 100
label = [[] for i in range(len(x_values))]
for i in range(len(x_values)):
    label[i] = '{} ({:.2f}%)'.format(x_values[i],percent[i])

fig, axs = plt.subplots(figsize=(5, 5)) # change figure size here
pie = axs.pie(y_values, shadow=True, startangle=90)
axs.axis('equal')
plt.legend(pie[0],label, bbox_to_anchor=(1.3,0.5), loc="center right", fontsize=12, 
           bbox_transform=plt.gcf().transFigure)
plt.title('COVID-19 Death Cases Broken Down by Race',fontweight="bold", fontsize=15, pad=20)
plt.show()

# %% [markdown]
# ## Conclusion:
#
# Just by observing the COVID-19 death cases brokwn down by race, we can conclude that there are more white deaths compared to other races. It seems that the number of white deaths is more than two times the number of black or Latin deaths.
#
# However, it is incorrect to say that white people are more likely to die from COVID compared to other races. Even though 60.1% of Americans are white, only 48.45% of COVID death cases are white. This suggests that white people are less likely to die from COVID compared to other race/ethnicity. We will do a detailed analysis of the race data in the next lab notebook.
